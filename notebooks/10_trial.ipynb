# %%
import pandas as pd
import os
from pathlib import Path
import numpy as np

# %%
df = pd.read_csv(os.path.join('F:\iNeuron\Projects\Data\Scania Truck Failures','aps_failure_training_set.csv'))

# %%
df.head()
# Out:
#   class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg   76698     na  2130706438    280      0      0      0      0      0
# 1   neg   33058     na           0     na      0      0      0      0      0
# 2   neg   41040     na         228    100      0      0      0      0      0
# 3   neg      12      0          70     66      0     10      0      0      0
# 4   neg   60874     na        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# 1      0
# ...

# %%
df['class'] = df['class'].map({'neg':0,'pos':1})
df.replace('na',np.nan,inplace=True)
col_list = [i for i in df.columns if i != 'class']
for i in col_list:
    df[i]=df[i].astype('float')

# %%
df.describe()
# Out:
#        class        aa_000        ab_000        ac_000        ad_000  \
# count    0.0  6.000000e+04  13671.000000  5.666500e+04  4.513900e+04
# mean     NaN  5.933650e+04      0.713189  3.560143e+08  1.906206e+05
# std      NaN  1.454301e+05      3.478962  7.948749e+08  4.040441e+07
# min      NaN  0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 25%      NaN  8.340000e+02      0.000000  1.600000e+01  2.400000e+01
# 50%      NaN  3.077600e+04      0.000000  1.520000e+02  1.260000e+02
# 75%      NaN  4.866800e+04      0.000000  9.640000e+02  4.300000e+02
# max      NaN  2.746564e+06    204.000000  2.130707e+09  8.584298e+09
#
#              ae_000        af_000        ag_000        ag_001        ag_002  \
# count  57500.000000  57500.000000  5.932900e+04  5.932900e+04  5.932900e+04
# mean       6.819130     11.006817  2.216364e+02  9.757223e+02  8.606015e+03
# std      161.543373    209.792592  2.047846e+04  3.420053e+04  1.503220e+05
# ...

# %% [markdown]
# # Test Data

# %%
os.path.join('F:\iNeuron\Projects\Scania_Truck_Failures\\artifacts\data\raw','train_data1.csv')
# Out:
# 'F:\\iNeuron\\Projects\\Scania_Truck_Failures\\artifacts\\data\raw\\train_data1.csv'

# %%
df_1 = pd.read_csv('..\\artifacts\\data\\raw\\train_data1.csv')
df_2 = pd.read_csv('..\\artifacts\\data\\raw\\train_data2.csv')
df_3 = pd.read_csv('..\\artifacts\\data\\raw\\train_data3.csv')

# %%
test_data_merger_1 = pd.merge(left = df_1,
                              right = df_2,
                              how = 'outer',
                              on = 'ident_id')
test_data_merger_final = pd.merge(left = test_data_merger_1,
                                  right = df_3,
                                  how = 'outer',
                                  on = 'ident_id')
test_data_merger_final_copy = test_data_merger_final.copy()

# %%
import numpy as np
test_data_merger_final_copy.drop(columns='ident_id',inplace=True)
test_data_merger_final_copy.rename(columns={'field_74_':'class'},inplace=True)
test_data_merger_final_copy['class'] = test_data_merger_final_copy['class'].map({'neg':0,'pos':1})
test_data_merger_final_copy.replace('na',np.nan,inplace=True)
test_col_list = [i for i in test_data_merger_final_copy.columns if i != 'class']
for i in test_col_list:
    test_data_merger_final_copy[i]=test_data_merger_final_copy[i].astype('float')

# %%
check_df = test_data_merger_final_copy.drop(columns='class').describe()==df.drop(columns='class').describe()
for i in check_df.columns:
    print(i,check_df[i].unique())
# Out:
# aa_000 [ True]
# ab_000 [ True]
# ac_000 [ True]
# ad_000 [ True]
# ae_000 [ True]
# af_000 [ True False]
# ag_000 [ True]
# ag_001 [ True False]
# ag_002 [ True]
# ag_003 [ True]
# ag_004 [ True]
# ag_005 [ True]
# ag_006 [ True]
# ag_007 [ True]
# ag_008 [ True]
# ag_009 [ True]
# ah_000 [ True]
# ai_000 [ True False]
# aj_000 [ True False]
# ak_000 [ True False]
# al_000 [ True False]
# am_0 [ True]
# an_000 [ True False]
# ao_000 [ True]
# ap_000 [ True]
# aq_000 [ True]
# ar_000 [ True]
# as_000 [ True False]
# at_000 [ True False]
# au_000 [ True]
# av_000 [ True]
# ax_000 [ True]
# ay_000 [ True False]
# ay_001 [ True False]
# ay_002 [ True False]
# ay_003 [ True False]
# ay_004 [ True]
# ay_005 [ True]
# ay_006 [ True False]
# ay_007 [ True False]
# ay_008 [ True]
# ay_009 [ True False]
# az_000 [ True False]
# az_001 [ True]
# az_002 [ True]
# az_003 [ True]
# az_004 [ True False]
# az_005 [ True]
# az_006 [ True]
# az_007 [ True]
# az_008 [ True]
# az_009 [ True False]
# ...

# %%
df['ag_001'].describe()==test_data_merger_final_copy['ag_001'].describe()
# Out:
# count     True
# mean      True
# std      False
# min       True
# 25%       True
# 50%       True
# 75%       True
# max       True
# Name: ag_001, dtype: bool

# %%
test_data_merger_final_copy.columns.tolist()
# Out:
# ['aa_000',
#  'ab_000',
#  'ac_000',
#  'ad_000',
#  'ae_000',
#  'af_000',
#  'ag_000',
#  'ag_001',
#  'ag_002',
#  'ag_003',
#  'ag_004',
#  'ag_005',
#  'ag_006',
#  'ag_007',
#  'ag_008',
#  'ag_009',
#  'ah_000',
#  'ai_000',
#  'aj_000',
#  'ak_000',
#  'al_000',
#  'am_0',
#  'an_000',
#  'ao_000',
#  'ap_000',
#  'aq_000',
#  'ar_000',
#  'as_000',
#  'at_000',
#  'au_000',
#  'av_000',
#  'ax_000',
#  'ay_000',
#  'ay_001',
#  'ay_002',
#  'ay_003',
#  'ay_004',
#  'ay_005',
#  'ay_006',
#  'ay_007',
#  'ay_008',
#  'ay_009',
#  'az_000',
#  'az_001',
#  'az_002',
#  'az_003',
#  'az_004',
#  'az_005',
#  'az_006',
#  'az_007',
#  'az_008',
#  'az_009',
#  'ba_000',
#  'ba_001',
#  'ba_002',
#  'ba_003',
#  'ba_004',
#  'ba_005',
#  'ba_006',
#  'ba_007',
#  'ba_008',
#  'ba_009',
#  'bb_000',
#  'bc_000',
#  'bd_000',
#  'be_000',
#  'bf_000',
#  'bg_000',
#  'bh_000',
#  'bi_000',
#  'bj_000',
#  'bk_000',
#  'bl_000',
#  'class',
#  'bm_000',
#  'bn_000',
#  'bo_000',
# ...

# %%
test_data_merger_final_copy['ag_001'].describe()
# Out:
# count    5.932900e+04
# mean     9.757223e+02
# std      3.420053e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.109372e+06
# Name: ag_001, dtype: float64

# %%
df['ag_001'].describe()
# Out:
# count    5.932900e+04
# mean     9.757223e+02
# std      3.420053e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.109372e+06
# Name: ag_001, dtype: float64
