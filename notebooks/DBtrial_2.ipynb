# %%
import os
os.chdir("f:\\iNeuron\\Projects\\scania_failures_2")

# %%
os.environ['ASTRA_DB_ID'] = 'a26b75d4-7da9-45a4-9b9d-9f243e9841bd'
os.environ['ASTRA_DB_REGION'] = 'asia-south1'
os.environ['ASTRA_DB_APPLICATION_TOKEN'] = 'AstraCS:wUxMCTOXnNGRUamWGBaHiKPZ:171f8f35ac8f0976579529e13c54b24c8015c1841314ad624026d577a5478bdf'
os.environ['ASTRA_DB_KEYSPACE'] = 'scania_truck_train_1'
ASTRA_DB_ID = os.environ.get('ASTRA_DB_ID')
ASTRA_DB_REGION = os.environ.get('ASTRA_DB_REGION')
ASTRA_DB_APPLICATION_TOKEN = os.environ.get('ASTRA_DB_APPLICATION_TOKEN')
ASTRA_DB_KEYSPACE = os.environ.get('ASTRA_DB_KEYSPACE')

# %%
from astrapy.ops import AstraDBOps

# Initialize the AstraDBOps client
client = AstraDBOps(token=ASTRA_DB_APPLICATION_TOKEN)

# %%
client.get_user()
# Out:
# {'OrgID': '7857e72a-5ca6-4026-a818-0438881dc3d7',
#  'OrgName': 'brajnarayanan.b@gmail.com',
#  'Users': [{'UserID': '49250b06-b400-49a5-a9bb-579f374e2951',
#    'Email': 'brajnarayanan.b@gmail.com',
#    'Status': 'active',
#    'Roles': [{'ID': 'ad0566b5-2a67-49de-89e8-92258c2f2c98',
#      'Name': 'Organization Administrator'}]}]}

# %%
db_by_id = client.get_database()
db_by_id
# Out:
# [{'availableActions': ['getCreds',
#    'addDatacenters',
#    'cloneDatabaseFromSnapshot',
#    'terminateDatacenter',
#    'migrateServerlessTenant',
#    'terminate',
#    'addKeyspace',
#    'removeKeyspace',
#    'suspend',
#    'createServerlessMigrationProxy',
#    'removeServerlessMigrationProxy',
#    'updateVectorAgent',
#    'getVectorAgentConfig',
#    'hibernate'],
#   'cost': {'costPerDayCents': 0,
#    'costPerDayMRCents': 0,
#    'costPerDayParkedCents': 0,
#    'costPerHourCents': 0,
#    'costPerHourMRCents': 0,
#    'costPerHourParkedCents': 0,
#    'costPerMinCents': 0,
#    'costPerMinMRCents': 0,
#    'costPerMinParkedCents': 0,
#    'costPerMonthCents': 0,
#    'costPerMonthMRCents': 0,
#    'costPerMonthParkedCents': 0,
#    'costPerNetworkGbCents': 0,
#    'costPerReadGbCents': 0.1,
#    'costPerWrittenGbCents': 0.1},
#   'cqlshUrl': 'https://ee8e1c88-1c33-416c-992c-20a8ae1a3f36-us-east1.apps.astra.datastax.com/cqlsh',
#   'creationTime': '2024-01-13T04:54:14Z',
#   'dataEndpointUrl': 'https://ee8e1c88-1c33-416c-992c-20a8ae1a3f36-us-east1.apps.astra.datastax.com/api/rest',
#   'grafanaUrl': 'https://ee8e1c88-1c33-416c-992c-20a8ae1a3f36-us-east1.dashboard.astra.datastax.com/d/cloud/dse-cluster-condensed?refresh=30s&orgId=1&kiosk=tv',
#   'graphqlUrl': 'https://ee8e1c88-1c33-416c-992c-20a8ae1a3f36-us-east1.apps.astra.datastax.com/api/graphql',
#   'id': 'ee8e1c88-1c33-416c-992c-20a8ae1a3f36',
#   'info': {'capacityUnits': 1,
#    'cloudProvider': 'GCP',
#    'datacenters': [{'capacityUnits': 1,
#      'cloudProvider': 'GCP',
#      'dateCreated': '2024-01-13T04:54:14Z',
#      'id': 'ee8e1c88-1c33-416c-992c-20a8ae1a3f36-1',
#      'isPrimary': True,
#      'name': 'dc-1',
#      'region': 'us-east1',
#      'regionClassification': 'standard',
#      'regionZone': 'na',
#      'secureBundleInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/ee8e1c88-1c33-416c-992c-20a8ae1a3f36-1/secure-connect-internal-scania-truck-failure-train-3.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=5c405d43d3c80e0ca7e8bb9b5d2d9653d467044fcd335182842cbba6681f5348',
#      'secureBundleMigrationProxyInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/ee8e1c88-1c33-416c-992c-20a8ae1a3f36-1/secure-connect-proxy-internal-scania-truck-failure-train-3.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=79497f2f7d9cc7cfb2c78448285bb11cf539e2201339b7b589aaaa3d71ccd660',
#      'secureBundleMigrationProxyUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/ee8e1c88-1c33-416c-992c-20a8ae1a3f36-1/secure-connect-proxy-scania-truck-failure-train-3.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=7b3ae30025815316d3b1affb91937417948af22e503abf40e37ec27aaa9155b4',
#      'secureBundleUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/ee8e1c88-1c33-416c-992c-20a8ae1a3f36-1/secure-connect-scania-truck-failure-train-3.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=20962e239827aecec8ffc6d8f0d1a3a63488994d85a77dcf8f031df5cc55c45d',
#      'status': '',
#      'tier': 'serverless'}],
#    'keyspace': 'scania_truck_failure_train3',
#    'keyspaces': ['scania_truck_failure_train3'],
#    'name': 'scania_truck_failure_train_3',
#    'region': 'us-east1',
#    'tier': 'serverless'},
#   'lastUsageTime': '2024-02-23T03:25:29Z',
#   'metrics': {'errorsTotalCount': 0,
#    'liveDataSizeBytes': 0,
#    'readRequestsTotalCount': 0,
#    'writeRequestsTotalCount': 0},
#   'observedStatus': 'ACTIVE',
#   'orgId': '7857e72a-5ca6-4026-a818-0438881dc3d7',
#   'ownerId': '49250b06-b400-49a5-a9bb-579f374e2951',
#   'status': 'ACTIVE',
#   'storage': {'nodeCount': 3, 'replicationFactor': 1, 'totalStorage': 5},
#   'terminationTime': '0001-01-01T00:00:00Z'},
#  {'availableActions': ['getCreds',
#    'addDatacenters',
#    'cloneDatabaseFromSnapshot',
#    'terminateDatacenter',
#    'migrateServerlessTenant',
#    'terminate',
#    'addKeyspace',
#    'removeKeyspace',
#    'suspend',
#    'createServerlessMigrationProxy',
#    'removeServerlessMigrationProxy',
#    'updateVectorAgent',
#    'getVectorAgentConfig',
#    'hibernate'],
#   'cost': {'costPerDayCents': 0,
#    'costPerDayMRCents': 0,
#    'costPerDayParkedCents': 0,
#    'costPerHourCents': 0,
#    'costPerHourMRCents': 0,
#    'costPerHourParkedCents': 0,
#    'costPerMinCents': 0,
#    'costPerMinMRCents': 0,
#    'costPerMinParkedCents': 0,
#    'costPerMonthCents': 0,
#    'costPerMonthMRCents': 0,
#    'costPerMonthParkedCents': 0,
#    'costPerNetworkGbCents': 0,
#    'costPerReadGbCents': 0.1,
#    'costPerWrittenGbCents': 0.1},
#   'cqlshUrl': 'https://c6166a63-a777-4f28-87f9-ad58ea7e27fc-asia-south1.apps.astra.datastax.com/cqlsh',
#   'creationTime': '2024-02-08T11:23:22Z',
#   'dataEndpointUrl': 'https://c6166a63-a777-4f28-87f9-ad58ea7e27fc-asia-south1.apps.astra.datastax.com/api/rest',
#   'grafanaUrl': 'https://c6166a63-a777-4f28-87f9-ad58ea7e27fc-asia-south1.dashboard.astra.datastax.com/d/cloud/dse-cluster-condensed?refresh=30s&orgId=1&kiosk=tv',
#   'graphqlUrl': 'https://c6166a63-a777-4f28-87f9-ad58ea7e27fc-asia-south1.apps.astra.datastax.com/api/graphql',
#   'id': 'c6166a63-a777-4f28-87f9-ad58ea7e27fc',
#   'info': {'capacityUnits': 1,
#    'cloudProvider': 'GCP',
#    'datacenters': [{'capacityUnits': 1,
#      'cloudProvider': 'GCP',
#      'dateCreated': '2024-02-08T11:23:22Z',
#      'id': 'c6166a63-a777-4f28-87f9-ad58ea7e27fc-1',
#      'isPrimary': True,
#      'name': 'dc-1',
#      'region': 'asia-south1',
#      'regionClassification': 'standard',
#      'regionZone': 'apac',
#      'secureBundleInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/c6166a63-a777-4f28-87f9-ad58ea7e27fc-1/secure-connect-internal-scania-truck-failure-train-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=1b3dfae3591096e5671f53b962a7239b012cd8fdd955675ac56d3a73ffe5be41',
#      'secureBundleMigrationProxyInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/c6166a63-a777-4f28-87f9-ad58ea7e27fc-1/secure-connect-proxy-internal-scania-truck-failure-train-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=0ce8c53c4f05e310513b7b4edc9914a9e07e88c48cea9bd7f0e5ac17ad7794a9',
#      'secureBundleMigrationProxyUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/c6166a63-a777-4f28-87f9-ad58ea7e27fc-1/secure-connect-proxy-scania-truck-failure-train-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=3562a8388c41ed54af7a5f7044523b10864859e094bfe358171b73096e5af10f',
#      'secureBundleUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/c6166a63-a777-4f28-87f9-ad58ea7e27fc-1/secure-connect-scania-truck-failure-train-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=052fb76d6a17ead7a898617d471af777808a662c58532cd1ab20fe489405849b',
#      'status': '',
#      'tier': 'serverless'}],
#    'keyspace': 'scania_truck_train_1',
#    'keyspaces': ['scania_truck_train_1'],
#    'name': 'scania_truck_failure_train_1',
#    'region': 'asia-south1',
#    'tier': 'serverless'},
#   'lastUsageTime': '2024-02-23T03:07:56Z',
#   'metrics': {'errorsTotalCount': 0,
#    'liveDataSizeBytes': 0,
#    'readRequestsTotalCount': 0,
#    'writeRequestsTotalCount': 0},
#   'observedStatus': 'ACTIVE',
#   'orgId': '7857e72a-5ca6-4026-a818-0438881dc3d7',
#   'ownerId': '49250b06-b400-49a5-a9bb-579f374e2951',
#   'status': 'ACTIVE',
#   'storage': {'nodeCount': 3, 'replicationFactor': 1, 'totalStorage': 5},
#   'terminationTime': '0001-01-01T00:00:00Z'},
#  {'availableActions': ['getCreds',
#    'addDatacenters',
#    'cloneDatabaseFromSnapshot',
#    'terminateDatacenter',
#    'migrateServerlessTenant',
#    'terminate',
#    'addKeyspace',
#    'removeKeyspace',
#    'suspend',
#    'createServerlessMigrationProxy',
#    'removeServerlessMigrationProxy',
#    'updateVectorAgent',
#    'getVectorAgentConfig',
#    'hibernate'],
#   'cost': {'costPerDayCents': 0,
#    'costPerDayMRCents': 0,
#    'costPerDayParkedCents': 0,
#    'costPerHourCents': 0,
#    'costPerHourMRCents': 0,
#    'costPerHourParkedCents': 0,
#    'costPerMinCents': 0,
#    'costPerMinMRCents': 0,
#    'costPerMinParkedCents': 0,
#    'costPerMonthCents': 0,
#    'costPerMonthMRCents': 0,
#    'costPerMonthParkedCents': 0,
#    'costPerNetworkGbCents': 0,
#    'costPerReadGbCents': 0.1,
#    'costPerWrittenGbCents': 0.1},
#   'cqlshUrl': 'https://468ca3c4-a24c-4621-a47a-759367b2695e-asia-south1.apps.astra.datastax.com/cqlsh',
#   'creationTime': '2024-02-08T11:24:00Z',
#   'dataEndpointUrl': 'https://468ca3c4-a24c-4621-a47a-759367b2695e-asia-south1.apps.astra.datastax.com/api/rest',
#   'grafanaUrl': 'https://468ca3c4-a24c-4621-a47a-759367b2695e-asia-south1.dashboard.astra.datastax.com/d/cloud/dse-cluster-condensed?refresh=30s&orgId=1&kiosk=tv',
#   'graphqlUrl': 'https://468ca3c4-a24c-4621-a47a-759367b2695e-asia-south1.apps.astra.datastax.com/api/graphql',
#   'id': '468ca3c4-a24c-4621-a47a-759367b2695e',
#   'info': {'capacityUnits': 1,
#    'cloudProvider': 'GCP',
#    'datacenters': [{'capacityUnits': 1,
#      'cloudProvider': 'GCP',
#      'dateCreated': '2024-02-08T11:24:00Z',
#      'id': '468ca3c4-a24c-4621-a47a-759367b2695e-1',
#      'isPrimary': True,
#      'name': 'dc-1',
#      'region': 'asia-south1',
#      'regionClassification': 'standard',
#      'regionZone': 'apac',
#      'secureBundleInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/468ca3c4-a24c-4621-a47a-759367b2695e-1/secure-connect-internal-scania-truck-failure-train-2.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=cf767c3dd35f253bb3411c807fa2646b03fd96d65ed2a371077172800bf15323',
#      'secureBundleMigrationProxyInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/468ca3c4-a24c-4621-a47a-759367b2695e-1/secure-connect-proxy-internal-scania-truck-failure-train-2.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=f7d6ebbd4a77e339fd4d884154457029079fda49bd73741298ff4903454dd599',
#      'secureBundleMigrationProxyUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/468ca3c4-a24c-4621-a47a-759367b2695e-1/secure-connect-proxy-scania-truck-failure-train-2.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=0d8f7187d26f9b24ef78454c832567f945c75022a19b13877343b449b26c2269',
#      'secureBundleUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/468ca3c4-a24c-4621-a47a-759367b2695e-1/secure-connect-scania-truck-failure-train-2.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=7edd7e399c621defb6295f29f6f2158522fffd8c3adb03210d6fbd9b1ec90058',
#      'status': '',
#      'tier': 'serverless'}],
#    'keyspace': 'scania_truck_train_2',
#    'keyspaces': ['scania_truck_train_2'],
#    'name': 'scania_truck_failure_train_2',
#    'region': 'asia-south1',
#    'tier': 'serverless'},
#   'lastUsageTime': '2024-02-23T03:07:51Z',
#   'metrics': {'errorsTotalCount': 0,
#    'liveDataSizeBytes': 0,
#    'readRequestsTotalCount': 0,
#    'writeRequestsTotalCount': 0},
#   'observedStatus': 'ACTIVE',
#   'orgId': '7857e72a-5ca6-4026-a818-0438881dc3d7',
#   'ownerId': '49250b06-b400-49a5-a9bb-579f374e2951',
#   'status': 'ACTIVE',
#   'storage': {'nodeCount': 3, 'replicationFactor': 1, 'totalStorage': 5},
#   'terminationTime': '0001-01-01T00:00:00Z'},
#  {'availableActions': ['resumeHibernatedCluster',
#    'getCreds',
#    'addKeyspace',
#    'removeKeyspace',
#    'terminate',
#    'terminateDatacenter',
#    'migrateServerlessTenant',
#    'notifyClusterTerminationDueToInactivity'],
#   'cost': {'costPerDayCents': 0,
#    'costPerDayMRCents': 0,
#    'costPerDayParkedCents': 0,
#    'costPerHourCents': 0,
#    'costPerHourMRCents': 0,
#    'costPerHourParkedCents': 0,
#    'costPerMinCents': 0,
#    'costPerMinMRCents': 0,
#    'costPerMinParkedCents': 0,
#    'costPerMonthCents': 0,
#    'costPerMonthMRCents': 0,
#    'costPerMonthParkedCents': 0,
#    'costPerNetworkGbCents': 0,
#    'costPerReadGbCents': 0.1,
#    'costPerWrittenGbCents': 0.1},
#   'cqlshUrl': 'https://0b508f29-b748-471c-9b9b-8d57a34b8838-asia-south1.apps.astra.datastax.com/cqlsh',
#   'creationTime': '2024-02-19T11:20:05Z',
#   'dataEndpointUrl': 'https://0b508f29-b748-471c-9b9b-8d57a34b8838-asia-south1.apps.astra.datastax.com/api/rest',
#   'grafanaUrl': 'https://0b508f29-b748-471c-9b9b-8d57a34b8838-asia-south1.dashboard.astra.datastax.com/d/cloud/dse-cluster-condensed?refresh=30s&orgId=1&kiosk=tv',
#   'graphqlUrl': 'https://0b508f29-b748-471c-9b9b-8d57a34b8838-asia-south1.apps.astra.datastax.com/api/graphql',
#   'id': '0b508f29-b748-471c-9b9b-8d57a34b8838',
#   'info': {'capacityUnits': 1,
#    'cloudProvider': 'GCP',
#    'datacenters': [{'capacityUnits': 1,
#      'cloudProvider': 'GCP',
#      'dateCreated': '2024-02-19T11:20:05Z',
#      'id': '0b508f29-b748-471c-9b9b-8d57a34b8838-1',
#      'isPrimary': True,
#      'name': 'dc-1',
#      'region': 'asia-south1',
#      'regionClassification': 'standard',
#      'regionZone': 'apac',
#      'secureBundleInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/0b508f29-b748-471c-9b9b-8d57a34b8838-1/secure-connect-internal-files-for-prediction-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=8ea047367fbb82452b2405b070299d2463bf0620a418a05468747332f0e8019b',
#      'secureBundleMigrationProxyInternalUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/0b508f29-b748-471c-9b9b-8d57a34b8838-1/secure-connect-proxy-internal-files-for-prediction-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=05e272662a1feee133e9151452c11b46b18907cad9679afb78de5f8441788ee3',
#      'secureBundleMigrationProxyUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/0b508f29-b748-471c-9b9b-8d57a34b8838-1/secure-connect-proxy-files-for-prediction-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=08d284a97f3fe79292ed627a8b07b52db4415631d1061599187fde71faba5c17',
#      'secureBundleUrl': 'https://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/0b508f29-b748-471c-9b9b-8d57a34b8838-1/secure-connect-files-for-prediction-1.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIA2AIQRQ76S2JCB77W%2F20240223%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20240223T145617Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=9a64a25e9eb50ae124055c258b4d25869c4db5a2fa4a846dbd5cf566408dc74b',
#      'status': '',
#      'tier': 'serverless'}],
#    'keyspace': 'files_for_prediction_1_keyspace',
#    'keyspaces': ['files_for_prediction_1_keyspace'],
#    'name': 'files_for_prediction_1',
#    'region': 'asia-south1',
#    'tier': 'serverless'},
#   'lastUsageTime': '2024-02-19T11:20:05Z',
#   'metrics': {'errorsTotalCount': 0,
#    'liveDataSizeBytes': 0,
#    'readRequestsTotalCount': 0,
#    'writeRequestsTotalCount': 0},
#   'observedStatus': 'HIBERNATED',
#   'orgId': '7857e72a-5ca6-4026-a818-0438881dc3d7',
#   'ownerId': '49250b06-b400-49a5-a9bb-579f374e2951',
#   'status': 'HIBERNATED',
#   'storage': {'nodeCount': 3, 'replicationFactor': 1, 'totalStorage': 5},
#   'terminationTime': '0001-01-01T00:00:00Z'}]

# %%
db_by_id = client.get_secure_bundle()

# %%
db_by_id

# %%
client.

# %%
from astrapy.collections import create_client, AstraCollection
import uuid
import os

# get Astra connection information from environment variables


COLLECTION_NAME = "test"

# setup an Astra Client
astra_client = create_client(astra_database_id=ASTRA_DB_ID,
  astra_database_region=ASTRA_DB_REGION,
  astra_application_token=ASTRA_DB_APPLICATION_TOKEN)
collection = astra_client.namespace(ASTRA_DB_KEYSPACE).collection(COLLECTION_NAME)

# create a new document
cliff_uuid = str(uuid.uuid4())
print(f'Sending AstraCollection request using namespace: {ASTRA_DB_KEYSPACE}, collection: {COLLECTION_NAME}, and uuid: cliff_uuid')

response = collection.create(path=cliff_uuid, document={
  "first_name": "Cliff",
  "last_name": "Wicklow",
})

print (response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from astrapy.collections import create_client, AstraCollection
#       2 import uuid
#       3 import os
#
# ModuleNotFoundError: No module named 'astrapy.collections'
