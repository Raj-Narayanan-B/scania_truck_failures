# %% [markdown]
# # Train Data

# %% [markdown]
# ### Train Data - Batch 1

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

# %%
PlainTextAuthProvider('test_username','test_password').username
# Out:
# 'test_username'

# %%
cloud_config= {
    'secure_connect_bundle': r"F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\secure-connect-scania-truck-failure-1.zip"
    }
secrets = r'F:\iNeuron\Projects\scania_failures_2\Secrets\Tokens\scania_truck_failure_1-token.json'
config = [cloud_config,secrets]

# %%
cloud_config = {list(config[0].keys())[0] : list(config[0].values())[0]}

# %%
cloud_config
# Out:
# {'secure_connect_bundle': 'F:\\iNeuron\\Projects\\Data\\Scania Truck Failures\\Secrets\\Bundles\\secure-connect-scania-truck-failure-1.zip'}

# %%
cloud_config = {list(config[0].keys())[0] : list(config[0].values())[0]}
cloud_config
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 config =  list(cloud_config_)
# ----> 2 cloud_config = {list(config[0].keys())[0] : list(config[0].values())[0]}
#       3 cloud_config
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json
import pandas as pd
from pathlib import Path #type: ignore

def DB_Loader():
  # This secure connect bundle is autogenerated when you download your SCB, 
  # if yours is different update the file name below
  cloud_config= {
    'secure_connect_bundle': Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\secure-connect-scania-truck-failure-1.zip')
  }

  # This token JSON file is autogenerated when you download your token, 
  # if yours is different update the file name below
  with open(Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Tokens\scania_truck_failure_1-token.json')) as f:
      secrets = json.load(f)

  CLIENT_ID = secrets["clientId"]
  CLIENT_SECRET = secrets["secret"]

  auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
  cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
  session = cluster.connect()

  keyspace = "scania_truck_failure1"
  table = "train_data1"
  query = f"SELECT * FROM {keyspace}.{table}"

  # Execute the query
  result = session.execute(query)

  df_train_1 = pd.DataFrame(list(result))
  return df_train_1

# %%
df_train_1.shape
# Out:
# (60000, 75)

# %%
df_train_1.head()
# Out:
#    ident_id   aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001  ag_002  \
# 0      4317     2184     na    216    140      0      0      0      0       0
# 1     51678      124     na      8      6      0      0      0      0       0
# 2     35262  1084202     na     na     na      0      0      0   3808  419386
# 3     54191      356     na      0     na      0      0      0      0       0
# 4     25269      194      4     32     10      0      0      0      0       0
#
#    ... bd_000 be_000 bf_000    bg_000  bh_000   bi_000   bj_000   bk_000  \
# 0  ...     40     46      0     83702    4020    31144    31022       na
# 1  ...     16    130      0      6366     348     8060     3386  1310700
# 2  ...     na  57326      0  20994370  623010  7717282  6533948   240060
# 3  ...    132     48      0     12872     604     2808     4496       na
# 4  ...     12     44      0     43820    1142    17586    16034       na
#
#     bl_000 field_74_
# 0       na       neg
# ...

# %%
df_train_1.sort_values(by='ident_id').reset_index(drop = True)
# Out:
#        ident_id  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0             1   76698     na  2130706438    280      0      0      0      0
# 1             2   33058     na           0     na      0      0      0      0
# 2             3   41040     na         228    100      0      0      0      0
# 3             4      12      0          70     66      0     10      0      0
# 4             5   60874     na        1368    458      0      0      0      0
# ...         ...     ...    ...         ...    ...    ...    ...    ...    ...
# 59995     59996  153002     na         664    186      0      0      0      0
# 59996     59997    2286     na  2130706538    224      0      0      0      0
# 59997     59998     112      0  2130706432     18      0      0      0      0
# 59998     59999   80292     na  2130706432    494      0      0      0      0
# 59999     60000   40222     na         698    628      0      0      0      0
#
# ...

# %% [markdown]
# ### Train Data - Batch 2

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json
import pandas as pd
from pathlib import Path #type: ignore

# This secure connect bundle is autogenerated when you download your SCB, 
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\secure-connect-scania-truck-failure-train-2.zip')
}

# This token JSON file is autogenerated when you download your token, 
# if yours is different update the file name below
with open(Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Tokens\scania_truck_failure_train_2-token.json')) as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

keyspace = "scania_truck_failure_train2"
table = "train_data2"
query = f"SELECT * FROM {keyspace}.{table}"

# Execute the query
result = session.execute(query)

df_train_2 = pd.DataFrame(list(result))

# %%
df_train_2.shape
# Out:
# (60000, 75)

# %%
df_train_2.head()
# Out:
#    ident_id   bm_000   bn_000   bo_000   bp_000   bq_000   br_000  bs_000  \
# 0      4317       na       na       na       na       na       na   61420
# 1     51678  1310700  1310700  1310700  1310700  1310700  1310700   11120
# 2     35262   210000   278700   312860   387020   327700   259560  168540
# 3     54191       na       na       na       na       na       na    7120
# 4     25269       na       na       na       na       na       na   32900
#
#        bt_000    bu_000  ... di_000 dj_000 dk_000 dl_000 dm_000  dn_000  \
# 0     2184.71    228864  ...      0      0      0      0      0    2190
# 1      124.08     32018  ...      0      0      0      0      0     378
# 2  1084202.47  66124446  ...     na     na     na     na     na  351538
# 3      356.35     37558  ...      0      0      0      0      0     292
# 4      194.59    144744  ...  23712      0      0      0      0    1022
#
#   do_000 dp_000  dq_000 dr_000
# 0    686    108  434580  74572
# ...

# %%
df_train_2.sort_values(by='ident_id').reset_index(drop = True)
# Out:
#        ident_id  bm_000  bn_000  bo_000  bp_000  bq_000  br_000  bs_000  \
# 0             1  299160  305200  283680      na      na      na  178540
# 1             2  366560      na      na      na      na      na    6700
# 2             3      na      na      na      na      na      na   28000
# 3             4      na      na      na      na      na      na   10580
# 4             5  274180      na      na      na      na      na  189000
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 59995     59996  221100  245580  152420  212500  151980  199220  247880
# 59996     59997      na      na      na      na      na      na   23720
# 59997     59998      na      na      na      na      na      na   13440
# 59998     59999  308960  282140  362360      na      na      na   18940
# 59999     60000      na      na      na      na      na      na  107280
#
#           bt_000    bu_000  ...  di_000 dj_000 dk_000 dl_000 dm_000 dn_000  \
# ...

# %% [markdown]
# ### Train Data - Batch 3

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json
import pandas as pd
from pathlib import Path #type: ignore

# This secure connect bundle is autogenerated when you download your SCB, 
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\secure-connect-scania-truck-failure-train-3.zip')
}

# This token JSON file is autogenerated when you download your token, 
# if yours is different update the file name below
with open(Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Tokens\scania_truck_failure_train_3-token.json')) as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

keyspace = "scania_truck_failure_train3"
table = "train_data3"
query = f"SELECT * FROM {keyspace}.{table}"

# Execute the query
result = session.execute(query)

df_train_3 = pd.DataFrame(list(result))

# %%
df_train_3.shape
# Out:
# (60000, 24)

# %%
df_train_3.head()
# Out:
#    ident_id ds_000 dt_000 du_000 dv_000  dx_000 dy_000 dz_000 ea_000 eb_000  \
# 0      4317   9554   1558  43040   4764  122872   1068      0      0      0
# 1     51678    322     86      0      0       0     74      0      0      0
# 2     35262     na     na     na     na      na     na     na     na     na
# 3     54191      0      0      0      0       0      0      0      0      0
# 4     25269    372     98  15600   1600       0      0      0      0      0
#
#    ...   ee_002   ee_003   ee_004   ee_005   ee_006    ee_007  ee_008 ee_009  \
# 0  ...    26274     9248    14664    15206     9218     19196     608      0
# 1  ...     1374     1024      886      866      824       530       0      0
# 2  ...  4202504  1981468  3487824  2839146  4794056  27733074  586816     16
# 3  ...     1688      656     2448    10440       64         0       0      0
# 4  ...     1658      612     1556      862     3340        26       2      0
#
#   ef_000 eg_000
# 0      0      0
# ...

# %%
df_train_3.sort_values(by='ident_id').reset_index(drop = True)
# Out:
#        ident_id  ds_000 dt_000    du_000   dv_000 dx_000 dy_000 dz_000 ea_000  \
# 0             1  202710  37928  14745580  1876644      0      0      0      0
# 1             2  103330  16254   4510080   868538      0      0      0      0
# 2             3   65772  10534    300240    48028      0      0      0      0
# 3             4      48     18     15740     1822  20174     44      0      0
# 4             5  149474  35154    457040    80482  98334  27588      0      0
# ...         ...     ...    ...       ...      ...    ...    ...    ...    ...
# 59995     59996  265640  54496    470800   293652      0      0      0      0
# 59996     59997    2450    510    823720    82346  16440     20      0      0
# 59997     59998     162     58      7920      784   9112      0      0      0
# 59998     59999  166748  40564  25232340  5648346      0      0      0      0
# 59999     60000   79872  14390    152740    17080      0      0      0      0
#
# ...

# %% [markdown]
# ### Concatenation of Train Data Batches

# %%
df_merger_1 = pd.merge(left=df_train_1,
         right=df_train_2,
         how = 'outer',
         on = 'ident_id')#.to_csv(Path('F:\\iNeuron\\Projects\\Data\\Scania Truck Failures\\train_data_merger.csv'),index=False)

# %%
df_merger_1.head()
# Out:
#    ident_id   aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001  ag_002  \
# 0      4317     2184     na    216    140      0      0      0      0       0
# 1     51678      124     na      8      6      0      0      0      0       0
# 2     35262  1084202     na     na     na      0      0      0   3808  419386
# 3     54191      356     na      0     na      0      0      0      0       0
# 4     25269      194      4     32     10      0      0      0      0       0
#
#    ... di_000 dj_000 dk_000 dl_000 dm_000  dn_000 do_000 dp_000  dq_000 dr_000
# 0  ...      0      0      0      0      0    2190    686    108  434580  74572
# 1  ...      0      0      0      0      0     378      0      2    2880   1288
# 2  ...     na     na     na     na     na  351538     na     na      na     na
# 3  ...      0      0      0      0      0     292      0      0       0      0
# 4  ...  23712      0      0      0      0    1022     20      2       0      0
#
# [5 rows x 149 columns]

# %%
df_merger_2 = pd.merge(left=df_merger_1,
         right=df_train_3,
         how = 'outer',
         on = 'ident_id').sort_values(by='ident_id')#.to_csv(Path('F:\\iNeuron\\Projects\\Data\\Scania Truck Failures\\train_data_merger.csv'),index=False)

# %% [markdown]
# ### Treatment of Newly Merged DF

# %% [markdown]
# #### Rename TARGET column from 'field_74_' to 'class'

# %%
df_merger_2.rename(columns={"field_74_": "class"},inplace=True)

# %%
df_merger_2_copy = df_merger_2.copy()

# %% [markdown]
# #### Reset_index in the merged df

# %%
df_merger_2_copy = df_merger_2_copy.reset_index(drop=True).drop(columns=['ident_id'])

# %%
df_merger_2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 171 entries, aa_000 to eg_000
# dtypes: int64(1), object(170)
# memory usage: 78.3+ MB

# %%
df_merger_2_copy['class'].unique()
# Out:
# array(['neg', 'pos'], dtype=object)

# %% [markdown]
# #### map 'neg' & 'pos' in class to '0' & '1' in 'class' column

# %%
df_merger_2_copy['class'] = df_merger_2_copy['class'].map({'neg':0,'pos':1})

# %%
df_merger_2_copy['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# #### Create a list containing column names without the 'class' column name

# %%
cols = [i for i in df_merger_2_copy.columns if i!='class']

# %%
'class' in cols
# Out:
# False

# %%
len(cols)
# Out:
# 170

# %%
import numpy as np

# %% [markdown]
# #### Replace 'na' in df to np.nan

# %%
df_merger_2_copy.replace('na',np.nan,inplace=True)

# %% [markdown]
# #### Convert datatype of columns to float

# %%
for i in cols:
    df_merger_2_copy[i] = df_merger_2_copy[i].astype(dtype='float')

# %%
df_merger_2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 171 entries, aa_000 to eg_000
# dtypes: float64(170), int64(1)
# memory usage: 78.3 MB

# %%
df_merger_2_copy.dtypes
# Out:
# aa_000    float64
# ab_000    float64
# ac_000    float64
# ad_000    float64
# ae_000    float64
#            ...
# ee_007    float64
# ee_008    float64
# ee_009    float64
# ef_000    float64
# eg_000    float64
# Length: 171, dtype: object

# %% [markdown]
# #### check .describe() of the treated df

# %%
df_merger_2_copy.describe()
# Out:
#              aa_000        ab_000        ac_000        ad_000        ae_000  \
# count  6.000000e+04  13671.000000  5.666500e+04  4.513900e+04  57500.000000
# mean   5.933650e+04      0.713189  3.560143e+08  1.906206e+05      6.819130
# std    1.454301e+05      3.478962  7.948749e+08  4.040441e+07    161.543373
# min    0.000000e+00      0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    8.340000e+02      0.000000  1.600000e+01  2.400000e+01      0.000000
# 50%    3.077600e+04      0.000000  1.520000e+02  1.260000e+02      0.000000
# 75%    4.866800e+04      0.000000  9.640000e+02  4.300000e+02      0.000000
# max    2.746564e+06    204.000000  2.130707e+09  8.584298e+09  21050.000000
#
#              af_000        ag_000        ag_001        ag_002        ag_003  \
# count  57500.000000  5.932900e+04  5.932900e+04  5.932900e+04  5.932900e+04
# mean      11.006817  2.216364e+02  9.757223e+02  8.606015e+03  8.859128e+04
# ...

# %% [markdown]
# # Test Data

# %% [markdown]
# ### Test Data retrieval from DB

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json
import pandas as pd
from pathlib import Path #type: ignore

cloud_config_test_data_1= {
  'secure_connect_bundle': Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\Test Data Bundles\secure-connect-scania-truck-failure-test1.zip')
}
cloud_config_test_data_2= {
  'secure_connect_bundle': Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\Test Data Bundles\secure-connect-scania-truck-failure-test2.zip')
}
cloud_config_test_data_3= {
  'secure_connect_bundle': Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Bundles\Test Data Bundles\secure-connect-scania-truck-failure-test3.zip')
}

token_config_test_data_1 = Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Tokens\Test Data Tokens\scania_truck_failure_test1-token.json')
token_config_test_data_2 = Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Tokens\Test Data Tokens\scania_truck_failure_test2-token.json')
token_config_test_data_3 = Path('F:\iNeuron\Projects\Data\Scania Truck Failures\Secrets\Tokens\Test Data Tokens\scania_truck_failure_test3-token.json')

key_space_test_data_1 = 'scania_truck_failure_test_1'
key_space_test_data_2 = 'scania_truck_failure_test_2'
key_space_test_data_3 = 'scania_truck_failure_test_3'

table_test_data_1 = 'test_data1'
table_test_data_2 = 'test_data2'
table_test_data_3 = 'test_data3'


test_data_config = [[cloud_config_test_data_1, token_config_test_data_1, key_space_test_data_1, table_test_data_1],
                    [cloud_config_test_data_2, token_config_test_data_2, key_space_test_data_2, table_test_data_2],
                    [cloud_config_test_data_3, token_config_test_data_3, key_space_test_data_3, table_test_data_3]]

test_data_frames = []

for value in test_data_config:
  with open(value[1]) as f:
    secrets = json.load(f)

  CLIENT_ID = secrets["clientId"]
  CLIENT_SECRET = secrets["secret"]

  auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
  cluster = Cluster(cloud=value[0], auth_provider=auth_provider)
  session = cluster.connect()
  
  keyspace = value[2]
  table = value[3]
  query = f"SELECT * FROM {keyspace}.{table}"

  result = session.execute(query)

  test_data_frames.append(pd.DataFrame(list(result)))

# %%
test_data_frames[0]
# Out:
#        ident_id  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0          4317     464      0          12     12      0      0     na     na
# 1          3372    1614      2           8      6      0      0      0      0
# 2         14340   55896     na          74     70      0      0      0      0
# 3          1584   39698     na        1740    966      0      0      0      0
# 4          7034      38     na          48     36      0      0      0      0
# ...         ...     ...    ...         ...    ...    ...    ...    ...    ...
# 15995      5504   58286     na  2130706432    434      0      0      0      0
# 15996      3476  693678      0         770      0      0      0      0      0
# 15997      2542   58090      0  2130706432     na      0      0      0      0
# 15998      6931       8      0           4      4      0      0      0      0
# 15999     11033   61026     na        1044    826      0      0      0      0
#
# ...

# %%
test_data_frames[1]
# Out:
#        ident_id  bm_000  bn_000  bo_000  bp_000  bq_000  br_000  bs_000  \
# 0          4317      na      na      na      na      na      na   37640
# 1          3372      na      na      na      na      na      na   54260
# 2         14340  177120      na      na      na      na      na   17600
# 3          1584      na      na      na      na      na      na  142460
# 4          7034      na      na      na      na      na      na    7620
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 15995      5504  226260      na      na      na      na      na  108720
# 15996      3476  125400  148440  136200  143160  136440  185080   20320
# 15997      2542  349420      na      na      na      na      na   36100
# 15998      6931      na      na      na      na      na      na   13860
# 15999     11033  239840  247140      na      na      na      na   21920
#
#           bt_000    bu_000  ... di_000 dj_000 dk_000 dl_000 dm_000  dn_000  \
# ...

# %%
test_data_frames[2]
# Out:
#        ident_id  ds_000  dt_000    du_000   dv_000    dx_000 dy_000 dz_000  \
# 0          4317     500     120         0        0         0     80      0
# 1          3372    1430     564      1720      252     26562     92      0
# 2         14340   78442   15612    616080   104012         0      0      0
# 3          1584  111972   19566  11774260  1187164         0      0      0
# 4          7034     280      80      1020      102         0      0      0
# ...         ...     ...     ...       ...      ...       ...    ...    ...
# 15995      5504   82976   15020  15097300  1711582         0      0      0
# 15996      3476  963122  166570    278800   107954  38288358  11238      0
# 15997      2542  106484   14824  22209280  2375552         0      0      0
# 15998      6931      54      14      3700      416         6      4      0
# 15999     11033  147566   22782    906620   169294   4654326   2868      0
#
# ...

# %%
test_data_merger_1 = pd.merge(left = test_data_frames[0],
                              right = test_data_frames[1],
                              how = 'outer',
                              on = 'ident_id')

# %%
test_data_merger_final = pd.merge(left = test_data_merger_1,
                                  right = test_data_frames[2],
                                  how = 'outer',
                                  on = 'ident_id')

# %%
test_data_merger_final = test_data_merger_final.sort_values(by='ident_id').reset_index(drop=True)

# %%
# test_data_merger_final.to_csv(Path('F:\\iNeuron\\Projects\\Data\\Scania Truck Failures\\test_data_merger.csv'),index=False)

# %%
test_data_merger_final.head()
# Out:
#    ident_id  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0         1      60      0     20     12      0      0      0      0      0
# 1         2      82      0     68     40      0      0      0      0      0
# 2         3   66002      2    212    112      0      0      0      0      0
# 3         4   59816     na   1010    936      0      0      0      0      0
# 4         5    1814     na    156    140      0      0      0      0      0
#
#    ...  ee_002  ee_003  ee_004  ee_005   ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...    1098     138     412     654       78      88       0      0      0
# 1  ...    1068     276    1620     116       86     462       0      0      0
# 2  ...  495076  380368  440134  269556  1315022  153680     516      0      0
# 3  ...  540820  243270  483302  485332   431376  210074  281662   3232      0
# 4  ...    7646    4144   18466   49782     3176     482      76      0      0
#
#   eg_000
# 0      0
# 1      0
# ...

# %%
test_data_merger_final_copy = test_data_merger_final.copy()

# %%
import numpy as np
test_data_merger_final_copy.drop(columns='ident_id',inplace=True)
test_data_merger_final_copy.rename(columns={'field_74_':'class'},inplace=True)
test_data_merger_final_copy['class'] = test_data_merger_final_copy['class'].map({'neg':0,'pos':1})
test_data_merger_final_copy.replace('na',np.nan,inplace=True)
test_col_list = [i for i in test_data_merger_final_copy.columns if i != 'class']
for i in test_col_list:
    test_data_merger_final_copy[i]=test_data_merger_final_copy[i].astype('float')

# %%
test_data_merger_final_copy['class'].dtype
# Out:
# dtype('int64')

# %%
test_data_merger_final_copy.describe()
# Out:
#              aa_000       ab_000        ac_000        ad_000        ae_000  \
# count  1.600000e+04  3637.000000  1.507400e+04  12019.000000  15310.000000
# mean   6.799698e+04     0.772065  3.580393e+08    439.498794      6.428347
# std    5.035350e+05     2.589224  7.966968e+08   1551.328109    118.186469
# min    0.000000e+00     0.000000  0.000000e+00      0.000000      0.000000
# 25%    9.280000e+02     0.000000  1.600000e+01     26.000000      0.000000
# 50%    3.098200e+04     0.000000  1.590000e+02    130.000000      0.000000
# 75%    4.947900e+04     0.000000  1.003500e+03    430.000000      0.000000
# max    4.294967e+07    58.000000  2.130707e+09  87038.000000  11044.000000
#
#              af_000         ag_000        ag_001        ag_002        ag_003  \
# count  15310.000000   15811.000000  1.581100e+04  1.581100e+04  1.581100e+04
# mean      10.195950     120.858516  2.064204e+03  1.379236e+04  1.126276e+05
# ...

# %% [markdown]
# ### Original Test Data from local

# %%
test_df = pd.read_csv(Path('F:\\iNeuron\\Projects\\Data\\Scania Truck Failures\\aps_failure_test_set.csv'))

# %%
test_df_copy = test_df.copy()
test_df_copy['class'] = test_df_copy['class'].map({'neg':0,'pos':1})
test_df_copy.replace('na',np.nan,inplace=True)
test_col_list = [i for i in test_df_copy.columns if i != 'class']
for i in test_col_list:
    test_df_copy[i]=test_df_copy[i].astype('float')

# %%
test_df_copy.describe()
# Out:
#               class        aa_000       ab_000        ac_000        ad_000  \
# count  16000.000000  1.600000e+04  3637.000000  1.507400e+04  12019.000000
# mean       0.023438  6.799698e+04     0.772065  3.580393e+08    439.498794
# std        0.151293  5.035350e+05     2.589224  7.966968e+08   1551.328109
# min        0.000000  0.000000e+00     0.000000  0.000000e+00      0.000000
# 25%        0.000000  9.280000e+02     0.000000  1.600000e+01     26.000000
# 50%        0.000000  3.098200e+04     0.000000  1.590000e+02    130.000000
# 75%        0.000000  4.947900e+04     0.000000  1.003500e+03    430.000000
# max        1.000000  4.294967e+07    58.000000  2.130707e+09  87038.000000
#
#              ae_000        af_000         ag_000        ag_001        ag_002  \
# count  15310.000000  15310.000000   15811.000000  1.581100e+04  1.581100e+04
# mean       6.428347     10.195950     120.858516  2.064204e+03  1.379236e+04
# ...

# %% [markdown]
# ### Checking describe of retrieved data and original data

# %%
test_data_check = test_data_merger_final_copy.drop(columns='class').describe()==test_data_merger_final_copy.drop(columns='class').describe()

# %%
for i in test_data_check.columns:
    print (i,test_data_check[i].unique())
# Out:
# aa_000 [ True]
# ab_000 [ True]
# ac_000 [ True]
# ad_000 [ True]
# ae_000 [ True]
# af_000 [ True]
# ag_000 [ True]
# ag_001 [ True]
# ag_002 [ True]
# ag_003 [ True]
# ag_004 [ True]
# ag_005 [ True]
# ag_006 [ True]
# ag_007 [ True]
# ag_008 [ True]
# ag_009 [ True]
# ah_000 [ True]
# ai_000 [ True]
# aj_000 [ True]
# ak_000 [ True]
# al_000 [ True]
# am_0 [ True]
# an_000 [ True]
# ao_000 [ True]
# ap_000 [ True]
# aq_000 [ True]
# ar_000 [ True]
# as_000 [ True]
# at_000 [ True]
# au_000 [ True]
# av_000 [ True]
# ax_000 [ True]
# ay_000 [ True]
# ay_001 [ True]
# ay_002 [ True]
# ay_003 [ True]
# ay_004 [ True]
# ay_005 [ True]
# ay_006 [ True]
# ay_007 [ True]
# ay_008 [ True]
# ay_009 [ True]
# az_000 [ True]
# az_001 [ True]
# az_002 [ True]
# az_003 [ True]
# az_004 [ True]
# az_005 [ True]
# az_006 [ True]
# az_007 [ True]
# az_008 [ True]
# az_009 [ True]
# ba_000 [ True]
# ba_001 [ True]
# ba_002 [ True]
# ba_003 [ True]
# ba_004 [ True]
# ba_005 [ True]
# ...

# %%
from astrapy.db import AstraDB
import os
os.environ['ASTRA_DB_APPLICATION_TOKEN'] = 'AstraCS:ZhQoHKEDaoDmeurmDSxGPwRo:b4b5eba1acbad52900dd06eb997828717835bbacdd7e0aa16d3f9e9a4eaff4b6'
os.environ['ASTRA_DB_API_ENDPOINT'] = 'https://3670cf92-eb41-41b2-8e3d-c8a5f5d81913-us-east-2.apps.astra.datastax.com'
token_ = 'AstraCS:ZhQoHKEDaoDmeurmDSxGPwRo:b4b5eba1acbad52900dd06eb997828717835bbacdd7e0aa16d3f9e9a4eaff4b6'
api_endpoint_ = 'https://3670cf92-eb41-41b2-8e3d-c8a5f5d81913-us-east-2.apps.astra.datastax.com'
# Initialization
db = AstraDB(
  token=token_,
  api_endpoint=api_endpoint_,
  namespace='scania_truck_failure1')

print(f"Connected to Astra DB: {db.get_collections()}")
# Out:
# Connected to Astra DB: {'status': {'collections': []}}

# %%
db.collection('train_data1')
# Out:
# Astra DB Collection[name="train_data1", endpoint="https://3670cf92-eb41-41b2-8e3d-c8a5f5d81913-us-east-2.apps.astra.datastax.com"]

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json
import pandas as pd
from pathlib import Path #type: ignore

def DB_Loader():
  # This secure connect bundle is autogenerated when you download your SCB, 
  # if yours is different update the file name below
  cloud_config= {
    'secure_connect_bundle': Path('F:\iNeuron\Projects\scania_failures_2\Secrets\Bundles\secure-connect-scania-truck-failure-train-3.zip')
  }

  # This token JSON file is autogenerated when you download your token, 
  # if yours is different update the file name below
  with open(Path('F:\iNeuron\Projects\scania_failures_2\Secrets\Tokens\scania_truck_failure_train_3-token.json')) as f:
      secrets = json.load(f)

  CLIENT_ID = secrets["clientId"]
  CLIENT_SECRET = secrets["secret"]

  auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
  cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
  session = cluster.connect()

  keyspace = "scania_truck_failure_train3"
  table = "train_data3"
  query = f"SELECT * FROM {keyspace}.{table}"

  # Execute the query
  result = session.execute(query)

  df_train_1 = pd.DataFrame(list(result))
  return df_train_1

# %%
df = DB_Loader()

# %%
df
# Out:
#        ident_id  ds_000 dt_000  du_000 dv_000  dx_000 dy_000 dz_000 ea_000  \
# 0          4317    9554   1558   43040   4764  122872   1068      0      0
# 1         51678     322     86       0      0       0     74      0      0
# 2         35262      na     na      na     na      na     na     na     na
# 3         54191       0      0       0      0       0      0      0      0
# 4         25269     372     98   15600   1600       0      0      0      0
# ...         ...     ...    ...     ...    ...     ...    ...    ...    ...
# 59995     55834      na     na      na     na      na     na     na     na
# 59996     40920      78     24     540    804       0      8      0      0
# 59997     11033     408     92   21860   2176       0      0      0      0
# 59998     28249    1720    332   28480   3086       0      0      0      0
# 59999     56818  113932  18318  202560  29194  493060   5744      0      0
#
# ...

# %%
import subprocess
from src.config.configuration_manager import ConfigurationManager
import os
from pathlib import Path
import json
os.chdir("f:\\iNeuron\\Projects\\scania_failures_2")

# %%
config_obj = ConfigurationManager()
# Out:
# [2024-02-23 20:15:29,931: INFO: utils: config.yaml yaml_file is loaded]
# [2024-02-23 20:15:29,968: INFO: utils: params.yaml yaml_file is loaded]
# [2024-02-23 20:15:30,105: INFO: utils: schema.yaml yaml_file is loaded]
# [2024-02-23 20:15:30,139: INFO: utils: mlflow_config.yaml yaml_file is loaded]
# [2024-02-23 20:15:30,187: INFO: utils: mlflow_config.yaml yaml_file is loaded]
# [2024-02-23 20:15:30,191: INFO: utils: mlflow_config.yaml yaml_file is loaded]

# %%
data_df_path = config_obj.get_data_path_config().train_data1
keyspace = config_obj.get_astra_dB_data_config().train_data_1_key_space
table_name = config_obj.get_astra_dB_data_config().train_data_1_table
secure_connect_bundle = config_obj.get_astra_dB_data_config().train_data_1_secure_connect_bundle
token = config_obj.get_astra_dB_data_config().train_data_1_token
with open(token) as token_file:
    secrets = json.load(token_file)
CLIENT_ID = secrets['clientId']
CLIENT_SECRET = secrets['secret']
secrets
# Out:
# {'clientId': 'wUxMCTOXnNGRUamWGBaHiKPZ',
#  'secret': '6xWDJqa67lhgj+iDC9E4CUyv,W2MkG.X7g5I,pa6QKqjDSnn.QEFLI-HrB-rymbjNzb_cH6DN9Qr.0SYSllBLmJNwooe7E+MEwU711HqFOzYv6Tdo-fsp6GTohic6P,2',
#  'token': 'AstraCS:wUxMCTOXnNGRUamWGBaHiKPZ:171f8f35ac8f0976579529e13c54b24c8015c1841314ad624026d577a5478bdf'}

# %%
dsbulk_command = [
            "dsbulk",
            "unload",
            "-url", r"F:\iNeuron\Projects\scania_failures_2\artifacts\data\raw\train_data_1_sample.csv",
            "-k", keyspace,
            "-t", table_name,
            "-b", secure_connect_bundle,
            "-u", CLIENT_ID,
            "-p", CLIENT_SECRET,
        ]
subprocess.run(dsbulk_command, shell=True)
# Out:
# CompletedProcess(args=['dsbulk', 'unload', '-url', 'F:\\iNeuron\\Projects\\scania_failures_2\\artifacts\\data\\raw\\train_data_1_sample.csv', '-k', 'scania_truck_train_1', '-t', 'train_data1', '-b', 'f:\\iNeuron\\Projects\\scania_failures_2\\my_project_secrets\\Bundles\\secure-connect-scania-truck-failure-1.zip', '-u', 'wUxMCTOXnNGRUamWGBaHiKPZ', '-p', '6xWDJqa67lhgj+iDC9E4CUyv,W2MkG.X7g5I,pa6QKqjDSnn.QEFLI-HrB-rymbjNzb_cH6DN9Qr.0SYSllBLmJNwooe7E+MEwU711HqFOzYv6Tdo-fsp6GTohic6P,2'], returncode=0)

# %%
os.system(f"dsbulk unload -url 'F:/iNeuron/Projects/scania_failures_2/artifacts/data/raw/train_data_1_sample.csv' -k {keyspace} -t {table_name} -b {secure_connect_bundle} -u {CLIENT_ID} -p {CLIENT_SECRET}")
# Out:
# 0

# %%
os.system("dsbulk unload -url F:/iNeuron/Projects/scania_failures_2/artifacts/data/raw/train_data_1_sample.csv -k scania_truck_train_1 -t train_data1")
# Out:
# 0

# %%
CLIENT_ID
# Out:
# 'wUxMCTOXnNGRUamWGBaHiKPZ'

# %%
CLIENT_SECRET
# Out:
# '6xWDJqa67lhgj+iDC9E4CUyv,W2MkG.X7g5I,pa6QKqjDSnn.QEFLI-HrB-rymbjNzb_cH6DN9Qr.0SYSllBLmJNwooe7E+MEwU711HqFOzYv6Tdo-fsp6GTohic6P,2'
